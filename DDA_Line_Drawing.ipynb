# %% [markdown]
# <a href="https://colab.research.google.com/github/rafiafsan/Computer-Graphics-CSE342/blob/main/DDA_Line_Drawing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

def DDA(x0, y0, x1, y1):
    dx = abs(x1 - x0)
    dy = abs(y1 - y0)
    max_steps = max(dx, dy)
    x_increment = dx / max_steps
    y_increment = dy / max_steps
    x = float(x0)s
    y = float(y0)
    x_coordinates = []
    y_coordinates = []

    for _ in range(max_steps):
        x_coordinates.append(x)
        y_coordinates.append(y)
        print("x:", x, end=" ")
        print("y:", y, end="\n")
        x += x_increment
        y += y_increment

    plt.plot(x_coordinates, y_coordinates, marker='o', markersize=3, markerfacecolor="red")
    plt.title('DDA Line Drawing Algorithm')
    plt.xlabel('X-axis')
    plt.ylabel('Y-axis')
    plt.show()
# Out:
# x: 5.0 y: 5.0
# x: 6.0 y: 6.0
# x: 7.0 y: 7.0
# x: 8.0 y: 8.0
# x: 9.0 y: 9.0

# %%
DDA(5,5,10,10)
# Out:
# x: 5.0 y: 5.0
# x: 6.0 y: 6.0
# x: 7.0 y: 7.0
# x: 8.0 y: 8.0
# x: 9.0 y: 9.0
